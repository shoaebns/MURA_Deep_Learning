# %%
2+2
# Out:
# 4

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
import numpy as np

from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from itertools import chain
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.datasets import ImageFolder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
#       3 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
train_butterfly10 = ImageFolder('/Users/shoaebshaik/MURA_Deep_Learning/MURA-v1.1/train/XR_ELBOW', transform=Butterfly_trans)
test_butterfly10 = ImageFolder('MURA-v1.1/train/XR_ELBOW/patient00016', transform=Butterfly_trans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_butterfly10 = ImageFolder('/Users/shoaebshaik/MURA_Deep_Learning/MURA-v1.1/train/XR_ELBOW', transform=Butterfly_trans)
#       2 test_butterfly10 = ImageFolder('MURA-v1.1/train/XR_ELBOW/patient00016', transform=Butterfly_trans)
#
# NameError: name 'ImageFolder' is not defined
